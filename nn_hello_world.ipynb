# %% [markdown]
# <a href="https://colab.research.google.com/github/cloudtechlearncode/aws-cloudformation-examples/blob/master/nn_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 48.0160
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 38.1631
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 30.4035
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 24.2908
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 19.4739
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 15.6769
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 12.6822
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.3190
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4527
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9775
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8102
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8852
# ...

# %%
model.predict([10.0])
# Out:
# array([[18.976706]], dtype=float32)
